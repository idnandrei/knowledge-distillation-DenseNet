# %%
import tensorflow as tf
from tensorflow import keras

from keras import backend as K
from keras.models import Model
from keras.layers import Flatten, Dense, Dropout, Input
from keras.optimizers import Adam
from keras import layers, models
from keras.applications import DenseNet201
from keras.utils import image_dataset_from_directory
import numpy as np
from collections import Counter
from sklearn.utils import class_weight
import math
from keras.callbacks import ModelCheckpoint

# %%
class Distiller(tf.keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def get_config(self):
        config = super(Distiller, self).get_config()
        config.update({
            "student": self.student,
            "teacher": self.teacher
        })
        return config

    @classmethod
    def from_config(cls, config):
        student = config.pop("student")
        teacher = config.pop("teacher")
        return cls(student=student, teacher=teacher)

    def compile(
        self, optimizer, metrics, student_loss_fn, distillation_loss_fn, alpha=0.1, temperature=3
    ):
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        if len(data) == 3:
            x, y, sample_weight = data
        else:
            sample_weight = None
            x, y = data

        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            student_predictions = self.student(x, training=True)
            
            student_loss = self.student_loss_fn(
                y, 
                student_predictions,
                sample_weight=sample_weight
            )
            
            
            sparse_categorical_crossentropy = tf.keras.metrics.sparse_categorical_crossentropy(
                y, student_predictions
            )
            
            distillation_loss = self.distillation_loss_fn(
                tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                tf.nn.softmax(student_predictions / self.temperature, axis=1),
                sample_weight=sample_weight
            ) * self.temperature**2

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        gradients = tape.gradient(loss, self.student.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.student.trainable_variables))

        
        self.compiled_metrics.update_state(y, student_predictions, sample_weight=sample_weight)

       
        results = {m.name: m.result() for m in self.metrics}
        
      
        results.update({
            "student_loss": student_loss,
            "distillation_loss": distillation_loss,
            "sparse_categorical_crossentropy": tf.reduce_mean(sparse_categorical_crossentropy)
        })
        
        return results

    def test_step(self, data):
        if len(data) == 3:
            x, y, sample_weight = data
        else:
            sample_weight = None
            x, y = data

        student_predictions = self.student(x, training=False)
        
        student_loss = self.student_loss_fn(
            y, 
            student_predictions,
            sample_weight=sample_weight
        )
        
   
        sparse_categorical_crossentropy = tf.keras.metrics.sparse_categorical_crossentropy(
            y, student_predictions
        )

        
        self.compiled_metrics.update_state(y, student_predictions, sample_weight=sample_weight)

        results = {m.name: m.result() for m in self.metrics}
        
        results.update({
            "student_loss": student_loss,
            "sparse_categorical_crossentropy": tf.reduce_mean(sparse_categorical_crossentropy)
        })
            
        return results

    def call(self, inputs, training=None):
        return self.student(inputs, training=training)

# %%
import os
print("Directory exists:", os.path.exists(r'input/train_split'))
print("Directory contents:", os.listdir(r'input/train_split'))

img_gen = keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = img_gen.flow_from_directory(
    r'input/train_split',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    subset='training'
)

validation_generator = img_gen.flow_from_directory(
    r'input/train_split',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    subset='validation'
)
# Out:
# Directory exists: True
# Directory contents: ['0', '1', '4', '3', '2']
# Found 2931 images belonging to 5 classes.
# Found 731 images belonging to 5 classes.

# %%
def get_class_distribution(generator):
    labels = generator.classes
    return Counter(labels)


def compute_balanced_weights(class_counts):
    n_samples = sum(class_counts.values())
    n_classes = len(class_counts)
    smoothing_factor = 0.01
    weights = {
        cls: (n_samples / (n_classes * count)) * (1 - smoothing_factor) + (smoothing_factor * (n_samples / n_classes))
        for cls, count in class_counts.items()
    }
    total_weight = sum(weights.values())
    weights = {cls: weight/total_weight * n_classes for cls, weight in weights.items()}
    return weights

# Calculate weights
class_counts = get_class_distribution(train_generator)
print("Class distribution:", class_counts)


balanced_weights = compute_balanced_weights(class_counts)
class_weight_dict = balanced_weights

class_weight_dict
# Out:
# Class distribution: Counter({0: 1444, 2: 800, 1: 296, 4: 236, 3: 155})
# {0: 0.8113624824673042,
#  1: 1.013261575269528,
#  2: 0.8532688551440583,
#  3: 1.244280249490636,
#  4: 1.0778268376284745}

# %%
# Model setup
densenet201_base = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
densenet201_base.trainable = False

teacher = models.Sequential([
    densenet201_base,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.2),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(512, activation='relu'),
    layers.Dense(5, activation='softmax')
])
# Out:
# 2024-12-11 03:25:17.841011: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2024-12-11 03:25:17.841037: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-11 03:25:17.841044: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-11 03:25:17.841069: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-11 03:25:17.841083: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Load DenseNet-201 model
densenet201_base = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
densenet201_base.trainable = False 

# Create the teacher model
teacher = models.Sequential([
    densenet201_base,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.2),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(512, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# Create the student model
student = models.Sequential([
    layers.Input(shape=(224, 224, 3)),
    layers.Conv2D(48, (5, 5), strides=(2, 2), padding="same"),
    layers.ReLU(),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),

    layers.Conv2D(64, (3, 3), strides=(2, 2), padding="same"),
    layers.ReLU(),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),


    layers.Conv2D(128, (3, 3), strides=(2, 2), padding="same"),
    layers.ReLU(),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),

    layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
    layers.ReLU(),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),

    layers.Conv2D(256, (3, 3), strides=(1, 1), padding="same"),
    layers.ReLU(),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),

    layers.Conv2D(64, (3, 3), strides=(2, 2), padding="same"),
    layers.ReLU(),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),

    layers.Flatten(),
    layers.Dense(600, activation='relu'),
    layers.Dense(300, activation='relu'),
    layers.Dense(150, activation='relu'),
    layers.Dense(5, activation='softmax')
])

student.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 48)      3648
#
#  re_lu (ReLU)                (None, 112, 112, 48)      0
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 48)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        27712
#
#  re_lu_1 (ReLU)              (None, 28, 28, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         73856
#
#  re_lu_2 (ReLU)              (None, 7, 7, 128)         0
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 256)         295168
#
#  re_lu_3 (ReLU)              (None, 2, 2, 256)         0
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 256)         590080
#
#  re_lu_4 (ReLU)              (None, 1, 1, 256)         0
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 64)          147520
#
#  re_lu_5 (ReLU)              (None, 1, 1, 64)          0
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_6 (Dense)             (None, 600)               39000
#
#  dense_7 (Dense)             (None, 300)               180300
#
#  dense_8 (Dense)             (None, 150)               45150
#
#  dense_9 (Dense)             (None, 5)                 755
#
# =================================================================
# Total params: 1403189 (5.35 MB)
# Trainable params: 1403189 (5.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class MaxMinMetricsTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        super(MaxMinMetricsTracker, self).__init__()
        self.max_accuracy = float('-inf')
        self.min_crossentropy = float('inf')
        self.max_val_accuracy = float('-inf')
        self.min_val_crossentropy = float('inf')
        self.min_student_loss = float('inf')
        self.min_distillation_loss = float('inf')
    
    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            raise ValueError("Logs cannot be None")
            
        
        missing_metrics = [metric for metric in required_metrics if metric not in logs]
        if missing_metrics:
            raise ValueError(f"Missing required metrics: {missing_metrics}")
        
        # Update best metrics
        if logs['accuracy'] > self.max_accuracy:
            self.max_accuracy = logs['accuracy']
        
        if logs['sparse_categorical_crossentropy'] < self.min_crossentropy:
            self.min_crossentropy = logs['sparse_categorical_crossentropy']
            
        if logs['val_accuracy'] > self.max_val_accuracy:
            self.max_val_accuracy = logs['val_accuracy']
            
        if logs['val_sparse_categorical_crossentropy'] < self.min_val_crossentropy:
            self.min_val_crossentropy = logs['val_sparse_categorical_crossentropy']
            
        if logs['student_loss'] < self.min_student_loss:
            self.min_student_loss = logs['student_loss']
            
        if logs['distillation_loss'] < self.min_distillation_loss:
            self.min_distillation_loss = logs['distillation_loss']
        
        # Print current best metrics
        print(f"\nEpoch {epoch + 1} - Best Metrics:")
        print(f"Max accuracy: {self.max_accuracy:.4f}")
        print(f"Min crossentropy: {self.min_crossentropy:.4f}")
        print(f"Max val_accuracy: {self.max_val_accuracy:.4f}")
        print(f"Min val_crossentropy: {self.min_val_crossentropy:.4f}")
        print(f"Min student_loss: {self.min_student_loss:.4f}")
        print(f"Min distillation_loss: {self.min_distillation_loss:.4f}")

# Then, set up callbacks using the correct class name
callbacks = [
    
    ModelCheckpoint(
        filepath='best_model_og_with_class_weights',
        monitor='val_sparse_categorical_crossentropy',
        save_best_only=True,
        mode='min',
        save_weights_only=False,
        verbose=1
    ),
    
    MaxMinMetricsTracker() 
]

# %%
distiller = Distiller(student=student, teacher=teacher)

distiller.compile(
    optimizer=tf.keras.optimizers.legacy.Adam(
        learning_rate=1e-4,
        clipnorm=1.0,
        clipvalue=0.5 
    ),
    metrics=[
        tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
        tf.keras.metrics.SparseCategoricalCrossentropy(name='sparse_categorical_crossentropy')
    ],
    student_loss_fn=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    distillation_loss_fn=tf.keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=6.0
)

max_min_tracker = MaxMinMetricsTracker()

history = distiller.fit(
    train_generator,
    epochs=25,
    validation_data=validation_generator,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/25
# 2024-12-11 03:25:26.456269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 92/92 [==============================] - ETA: 0s - accuracy: 0.2726 - sparse_categorical_crossentropy: 1.3810 - student_loss: 1.3083 - distillation_loss: 0.0184
# Epoch 1: val_sparse_categorical_crossentropy improved from inf to 1.44449, saving model to best_model_og_with_class_weights
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# Epoch 1 - Best Metrics:
# Max accuracy: 0.2726
# Min crossentropy: 1.3810
# Max val_accuracy: 0.2722
# Min val_crossentropy: 1.4445
# Min student_loss: 1.2723
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 178s 2s/step - accuracy: 0.2726 - sparse_categorical_crossentropy: 1.3810 - student_loss: 1.3079 - distillation_loss: 0.0184 - val_accuracy: 0.2722 - val_sparse_categorical_crossentropy: 1.4445 - val_student_loss: 1.4445
# Epoch 2/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.2733 - sparse_categorical_crossentropy: 1.1785 - student_loss: 1.2642 - distillation_loss: 0.0161
# Epoch 2: val_sparse_categorical_crossentropy improved from 1.44449 to 1.17276, saving model to best_model_og_with_class_weights
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# Epoch 2 - Best Metrics:
# Max accuracy: 0.2733
# Min crossentropy: 1.1785
# Max val_accuracy: 0.3311
# Min val_crossentropy: 1.1728
# Min student_loss: 1.0552
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 175s 2s/step - accuracy: 0.2733 - sparse_categorical_crossentropy: 1.1785 - student_loss: 1.2620 - distillation_loss: 0.0161 - val_accuracy: 0.3311 - val_sparse_categorical_crossentropy: 1.1728 - val_student_loss: 1.1728
# Epoch 3/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.5206 - sparse_categorical_crossentropy: 1.1668 - student_loss: 1.1513 - distillation_loss: 0.0191
# Epoch 3: val_sparse_categorical_crossentropy did not improve from 1.17276
#
# Epoch 3 - Best Metrics:
# Max accuracy: 0.5206
# Min crossentropy: 1.1668
# Max val_accuracy: 0.5951
# Min val_crossentropy: 1.1728
# Min student_loss: 1.0552
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.5206 - sparse_categorical_crossentropy: 1.1668 - student_loss: 1.1504 - distillation_loss: 0.0190 - val_accuracy: 0.5951 - val_sparse_categorical_crossentropy: 1.2454 - val_student_loss: 1.2454
# Epoch 4/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6240 - sparse_categorical_crossentropy: 1.0570 - student_loss: 1.0442 - distillation_loss: 0.0213
# Epoch 4: val_sparse_categorical_crossentropy did not improve from 1.17276
#
# Epoch 4 - Best Metrics:
# Max accuracy: 0.6240
# Min crossentropy: 1.0570
# Max val_accuracy: 0.6375
# Min val_crossentropy: 1.1728
# Min student_loss: 0.9650
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6240 - sparse_categorical_crossentropy: 1.0570 - student_loss: 1.0433 - distillation_loss: 0.0213 - val_accuracy: 0.6375 - val_sparse_categorical_crossentropy: 1.2096 - val_student_loss: 1.2096
# Epoch 5/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6540 - sparse_categorical_crossentropy: 0.8951 - student_loss: 0.9945 - distillation_loss: 0.0223
# Epoch 5: val_sparse_categorical_crossentropy improved from 1.17276 to 1.01649, saving model to best_model_og_with_class_weights
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# Epoch 5 - Best Metrics:
# Max accuracy: 0.6540
# Min crossentropy: 0.8951
# Max val_accuracy: 0.6867
# Min val_crossentropy: 1.0165
# Min student_loss: 0.8496
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 173s 2s/step - accuracy: 0.6540 - sparse_categorical_crossentropy: 0.8951 - student_loss: 0.9929 - distillation_loss: 0.0222 - val_accuracy: 0.6867 - val_sparse_categorical_crossentropy: 1.0165 - val_student_loss: 1.0165
# Epoch 6/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6691 - sparse_categorical_crossentropy: 0.8896 - student_loss: 0.9857 - distillation_loss: 0.0233
# Epoch 6: val_sparse_categorical_crossentropy improved from 1.01649 to 0.76304, saving model to best_model_og_with_class_weights
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# Epoch 6 - Best Metrics:
# Max accuracy: 0.6691
# Min crossentropy: 0.8896
# Max val_accuracy: 0.6867
# Min val_crossentropy: 0.7630
# Min student_loss: 0.8435
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 173s 2s/step - accuracy: 0.6691 - sparse_categorical_crossentropy: 0.8896 - student_loss: 0.9842 - distillation_loss: 0.0234 - val_accuracy: 0.6744 - val_sparse_categorical_crossentropy: 0.7630 - val_student_loss: 0.7630
# Epoch 7/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6776 - sparse_categorical_crossentropy: 1.0614 - student_loss: 0.9708 - distillation_loss: 0.0225
# Epoch 7: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 7 - Best Metrics:
# Max accuracy: 0.6776
# Min crossentropy: 0.8896
# Max val_accuracy: 0.6867
# Min val_crossentropy: 0.7630
# Min student_loss: 0.8435
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6776 - sparse_categorical_crossentropy: 1.0614 - student_loss: 0.9714 - distillation_loss: 0.0224 - val_accuracy: 0.6443 - val_sparse_categorical_crossentropy: 1.0586 - val_student_loss: 1.0586
# Epoch 8/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6752 - sparse_categorical_crossentropy: 0.8447 - student_loss: 0.9650 - distillation_loss: 0.0227
# Epoch 8: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 8 - Best Metrics:
# Max accuracy: 0.6776
# Min crossentropy: 0.8447
# Max val_accuracy: 0.6867
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7371
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 158s 2s/step - accuracy: 0.6752 - sparse_categorical_crossentropy: 0.8447 - student_loss: 0.9625 - distillation_loss: 0.0227 - val_accuracy: 0.6156 - val_sparse_categorical_crossentropy: 1.1840 - val_student_loss: 1.1840
# Epoch 9/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6772 - sparse_categorical_crossentropy: 0.9428 - student_loss: 0.9620 - distillation_loss: 0.0225
# Epoch 9: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 9 - Best Metrics:
# Max accuracy: 0.6776
# Min crossentropy: 0.8447
# Max val_accuracy: 0.6949
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7371
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 160s 2s/step - accuracy: 0.6772 - sparse_categorical_crossentropy: 0.9428 - student_loss: 0.9611 - distillation_loss: 0.0225 - val_accuracy: 0.6949 - val_sparse_categorical_crossentropy: 1.2275 - val_student_loss: 1.2275
# Epoch 10/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6878 - sparse_categorical_crossentropy: 1.0462 - student_loss: 0.9562 - distillation_loss: 0.0225
# Epoch 10: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 10 - Best Metrics:
# Max accuracy: 0.6878
# Min crossentropy: 0.8447
# Max val_accuracy: 0.7018
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7371
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6878 - sparse_categorical_crossentropy: 1.0462 - student_loss: 0.9566 - distillation_loss: 0.0225 - val_accuracy: 0.7018 - val_sparse_categorical_crossentropy: 0.9306 - val_student_loss: 0.9306
# Epoch 11/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6936 - sparse_categorical_crossentropy: 0.7516 - student_loss: 0.9451 - distillation_loss: 0.0231
# Epoch 11: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 11 - Best Metrics:
# Max accuracy: 0.6936
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7018
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6936 - sparse_categorical_crossentropy: 0.7516 - student_loss: 0.9427 - distillation_loss: 0.0232 - val_accuracy: 0.7018 - val_sparse_categorical_crossentropy: 0.9491 - val_student_loss: 0.9491
# Epoch 12/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6923 - sparse_categorical_crossentropy: 0.8348 - student_loss: 0.9484 - distillation_loss: 0.0227
# Epoch 12: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 12 - Best Metrics:
# Max accuracy: 0.6936
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7018
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6923 - sparse_categorical_crossentropy: 0.8348 - student_loss: 0.9466 - distillation_loss: 0.0228 - val_accuracy: 0.6512 - val_sparse_categorical_crossentropy: 0.8240 - val_student_loss: 0.8240
# Epoch 13/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7015 - sparse_categorical_crossentropy: 1.0592 - student_loss: 0.9357 - distillation_loss: 0.0229
# Epoch 13: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 13 - Best Metrics:
# Max accuracy: 0.7015
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 157s 2s/step - accuracy: 0.7015 - sparse_categorical_crossentropy: 1.0592 - student_loss: 0.9361 - distillation_loss: 0.0229 - val_accuracy: 0.7155 - val_sparse_categorical_crossentropy: 0.8818 - val_student_loss: 0.8818
# Epoch 14/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7018 - sparse_categorical_crossentropy: 1.2049 - student_loss: 0.9318 - distillation_loss: 0.0227
# Epoch 14: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 14 - Best Metrics:
# Max accuracy: 0.7018
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.7018 - sparse_categorical_crossentropy: 1.2049 - student_loss: 0.9339 - distillation_loss: 0.0227 - val_accuracy: 0.7114 - val_sparse_categorical_crossentropy: 1.0230 - val_student_loss: 1.0230
# Epoch 15/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6987 - sparse_categorical_crossentropy: 0.9720 - student_loss: 0.9357 - distillation_loss: 0.0230
# Epoch 15: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 15 - Best Metrics:
# Max accuracy: 0.7018
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6987 - sparse_categorical_crossentropy: 0.9720 - student_loss: 0.9359 - distillation_loss: 0.0231 - val_accuracy: 0.7059 - val_sparse_categorical_crossentropy: 1.0107 - val_student_loss: 1.0107
# Epoch 16/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7035 - sparse_categorical_crossentropy: 1.0571 - student_loss: 0.9338 - distillation_loss: 0.0230
# Epoch 16: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 16 - Best Metrics:
# Max accuracy: 0.7035
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.7035 - sparse_categorical_crossentropy: 1.0571 - student_loss: 0.9345 - distillation_loss: 0.0229 - val_accuracy: 0.7141 - val_sparse_categorical_crossentropy: 1.2023 - val_student_loss: 1.2023
# Epoch 17/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7025 - sparse_categorical_crossentropy: 1.0934 - student_loss: 0.9312 - distillation_loss: 0.0224
# Epoch 17: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 17 - Best Metrics:
# Max accuracy: 0.7035
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.7025 - sparse_categorical_crossentropy: 1.0934 - student_loss: 0.9319 - distillation_loss: 0.0223 - val_accuracy: 0.6607 - val_sparse_categorical_crossentropy: 0.9834 - val_student_loss: 0.9834
# Epoch 18/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7107 - sparse_categorical_crossentropy: 0.9271 - student_loss: 0.9290 - distillation_loss: 0.0231
# Epoch 18: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 18 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7155
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.7107 - sparse_categorical_crossentropy: 0.9271 - student_loss: 0.9289 - distillation_loss: 0.0231 - val_accuracy: 0.7018 - val_sparse_categorical_crossentropy: 0.9094 - val_student_loss: 0.9094
# Epoch 19/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7001 - sparse_categorical_crossentropy: 0.7640 - student_loss: 0.9380 - distillation_loss: 0.0225
# Epoch 19: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 19 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7128
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 157s 2s/step - accuracy: 0.7001 - sparse_categorical_crossentropy: 0.7640 - student_loss: 0.9355 - distillation_loss: 0.0226 - val_accuracy: 0.7045 - val_sparse_categorical_crossentropy: 0.9997 - val_student_loss: 0.9997
# Epoch 20/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6912 - sparse_categorical_crossentropy: 1.0095 - student_loss: 0.9213 - distillation_loss: 0.0248
# Epoch 20: val_sparse_categorical_crossentropy did not improve from 0.76304
#
# Epoch 20 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7155
# Min val_crossentropy: 0.7630
# Min student_loss: 0.7128
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.6912 - sparse_categorical_crossentropy: 1.0095 - student_loss: 0.9222 - distillation_loss: 0.0248 - val_accuracy: 0.7114 - val_sparse_categorical_crossentropy: 0.9277 - val_student_loss: 0.9277
# Epoch 21/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.6994 - sparse_categorical_crossentropy: 0.7572 - student_loss: 0.9298 - distillation_loss: 0.0233
# Epoch 21: val_sparse_categorical_crossentropy improved from 0.76304 to 0.69736, saving model to best_model_og_with_class_weights
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# INFO:tensorflow:Assets written to: best_model_og_with_class_weights/assets
# Epoch 21 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7168
# Min val_crossentropy: 0.6974
# Min student_loss: 0.7128
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 174s 2s/step - accuracy: 0.6994 - sparse_categorical_crossentropy: 0.7572 - student_loss: 0.9277 - distillation_loss: 0.0234 - val_accuracy: 0.7168 - val_sparse_categorical_crossentropy: 0.6974 - val_student_loss: 0.6974
# Epoch 22/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7066 - sparse_categorical_crossentropy: 0.9281 - student_loss: 0.9219 - distillation_loss: 0.0232
# Epoch 22: val_sparse_categorical_crossentropy did not improve from 0.69736
#
# Epoch 22 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7168
# Min val_crossentropy: 0.6974
# Min student_loss: 0.7128
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 156s 2s/step - accuracy: 0.7066 - sparse_categorical_crossentropy: 0.9281 - student_loss: 0.9213 - distillation_loss: 0.0231 - val_accuracy: 0.7018 - val_sparse_categorical_crossentropy: 1.2310 - val_student_loss: 1.2310
# Epoch 23/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7090 - sparse_categorical_crossentropy: 0.7705 - student_loss: 0.9211 - distillation_loss: 0.0227
# Epoch 23: val_sparse_categorical_crossentropy did not improve from 0.69736
#
# Epoch 23 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7168
# Min val_crossentropy: 0.6974
# Min student_loss: 0.6859
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 159s 2s/step - accuracy: 0.7090 - sparse_categorical_crossentropy: 0.7705 - student_loss: 0.9186 - distillation_loss: 0.0227 - val_accuracy: 0.6484 - val_sparse_categorical_crossentropy: 0.9652 - val_student_loss: 0.9652
# Epoch 24/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7100 - sparse_categorical_crossentropy: 0.8932 - student_loss: 0.9166 - distillation_loss: 0.0237
# Epoch 24: val_sparse_categorical_crossentropy did not improve from 0.69736
#
# Epoch 24 - Best Metrics:
# Max accuracy: 0.7107
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7168
# Min val_crossentropy: 0.6974
# Min student_loss: 0.6859
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 159s 2s/step - accuracy: 0.7100 - sparse_categorical_crossentropy: 0.8932 - student_loss: 0.9153 - distillation_loss: 0.0237 - val_accuracy: 0.6813 - val_sparse_categorical_crossentropy: 1.1164 - val_student_loss: 1.1164
# Epoch 25/25
# 92/92 [==============================] - ETA: 0s - accuracy: 0.7114 - sparse_categorical_crossentropy: 0.8170 - student_loss: 0.9229 - distillation_loss: 0.0226
# Epoch 25: val_sparse_categorical_crossentropy did not improve from 0.69736
#
# Epoch 25 - Best Metrics:
# Max accuracy: 0.7114
# Min crossentropy: 0.7516
# Max val_accuracy: 0.7168
# Min val_crossentropy: 0.6974
# Min student_loss: 0.6859
# Min distillation_loss: 0.0152
# 92/92 [==============================] - 163s 2s/step - accuracy: 0.7114 - sparse_categorical_crossentropy: 0.8170 - student_loss: 0.9212 - distillation_loss: 0.0226 - val_accuracy: 0.6977 - val_sparse_categorical_crossentropy: 0.8059 - val_student_loss: 0.8059

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image

# Read the test CSV file
test_df = pd.read_csv('input/aptos2019-blindness-detection/test.csv')


# Load the best model
best_model = tf.keras.models.load_model('best_model_og_with_class_weights')


def load_and_preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array / 255.0


predictions = []
processed_files = []
test_dir = 'input/aptos2019-blindness-detection/test_images'

try:
  
    if not os.path.exists(test_dir):
        raise ValueError(f"Test directory not found: {test_dir}")
    
    print(f"Processing images from: {test_dir}")
    
    
    for img_name in os.listdir(test_dir):
        if img_name.endswith(('.jpg', '.jpeg', '.png')):
            img_path = os.path.join(test_dir, img_name)
            
            
            img_array = load_and_preprocess_image(img_path)
            
            
            pred = best_model.predict(img_array, verbose=0)
            predictions.append(pred[0])
            
            
            processed_files.append(os.path.splitext(img_name)[0])
    
    
    predicted_classes = np.argmax(predictions, axis=1)
    
   
    results_df = pd.DataFrame({
        'id_code': processed_files,
        'predicted_class': predicted_classes
    })
    
  
    results_df = results_df.set_index('id_code').reindex(test_df['id_code']).reset_index()
    
    print("\nPrediction Results:")
    print(results_df.head())
    
   
    results_df.to_csv('test_predictions.csv', index=False)
    
   
    print("\nDistribution of predictions:")
    print(pd.Series(predicted_classes).value_counts().sort_index())
    
    print(f"\nTotal images processed: {len(processed_files)}")

except Exception as e:
    print(f"An error occurred: {str(e)}")
    raise
# Out:
# Processing images from: input/aptos2019-blindness-detection/test_images
#
# Prediction Results:
#         id_code  predicted_class
# 0  0005cfc8afb6                2
# 1  003f0afdcd15                2
# 2  006efc72b638                2
# 3  00836aaacf06                2
# 4  009245722fa4                2
#
# Distribution of predictions:
# 0     568
# 2    1360
# Name: count, dtype: int64
#
# Total images processed: 1928

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Plot training history
plt.figure(figsize=(15, 5))

# Plot accuracy metrics
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss metrics
plt.subplot(1, 2, 2)
plt.plot(history.history['sparse_categorical_crossentropy'], label='Training Crossentropy')
plt.plot(history.history['val_sparse_categorical_crossentropy'], label='Validation Crossentropy')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Plot additional training metrics
plt.figure(figsize=(15, 5))

# Plot student loss
plt.subplot(1, 2, 1)
plt.plot(history.history['student_loss'], label='Student Loss')
plt.title('Student Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot distillation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['distillation_loss'], label='Distillation Loss')
plt.title('Distillation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Print final best metrics
print("\nBest Training Metrics:")
print(f"Best Training Accuracy: {max(history.history['accuracy']):.4f}")
print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
print(f"Best Training Crossentropy: {min(history.history['sparse_categorical_crossentropy']):.4f}")
print(f"Best Validation Crossentropy: {min(history.history['val_sparse_categorical_crossentropy']):.4f}")
print(f"Best Student Loss: {min(history.history['student_loss']):.4f}")
print(f"Best Distillation Loss: {min(history.history['distillation_loss']):.4f}")

# Plot prediction distribution for test set
plt.figure(figsize=(10, 6))
pred_dist = pd.Series(predicted_classes).value_counts().sort_index()
plt.bar(range(len(pred_dist)), pred_dist.values)
plt.title('Distribution of Predictions on Test Set')
plt.xlabel('Predicted Class')
plt.ylabel('Count')
plt.xticks(range(len(pred_dist)))


for i, v in enumerate(pred_dist.values):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# Best Training Metrics:
# Best Training Accuracy: 0.7114
# Best Validation Accuracy: 0.7168
# Best Training Crossentropy: 0.7516
# Best Validation Crossentropy: 0.6974
# Best Student Loss: 0.6859
# Best Distillation Loss: 0.0152

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, log_loss

# Get predictions for validation set
val_predictions = best_model.predict(validation_generator)
val_predicted_classes = np.argmax(val_predictions, axis=1)
val_true_classes = validation_generator.classes

# Calculate confusion matrix
cm = confusion_matrix(val_true_classes, val_predicted_classes)


plt.figure(figsize=(20, 8))


plt.subplot(1, 2, 1)
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            cmap='Reds',
            xticklabels=['Class '+str(i) for i in range(5)],
            yticklabels=['Class '+str(i) for i in range(5)])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')


misclass_data = []
for true_class in range(5):
    for pred_class in range(5):
        if true_class != pred_class:
            count = cm[true_class][pred_class]
            if count > 0:
                misclass_data.append({
                    'True Class': f'Class {true_class}',
                    'Predicted Class': f'Class {pred_class}',
                    'Count': count,
                    'Percentage': (count / cm[true_class].sum()) * 100
                })

misclass_df = pd.DataFrame(misclass_data)
top_misclass = misclass_df.nlargest(10, 'Count')

plt.subplot(1, 2, 2)
bars = plt.bar(range(len(top_misclass)), top_misclass['Count'])
plt.xticks(range(len(top_misclass)), 
          [f"{row['True Class']} → {row['Predicted Class']}" 
           for _, row in top_misclass.iterrows()],
          rotation=45,
          ha='right')
plt.title('Top 10 Misclassifications')
plt.xlabel('Class Pairs (True → Predicted)')
plt.ylabel('Count')


for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height)}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# 23/23 [==============================] - 33s 1s/step
